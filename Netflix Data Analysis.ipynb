# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('netflix1.csv')
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df.shape
# Out:
# (7789, 11)

# %%
df.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
df[df.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %% [markdown]
# Drop.duplicated Values

# %%
df.drop_duplicates(inplace=True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %% [markdown]
# Cheaking Null Values

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %% [markdown]
# Using Heatmap to show null values

# %%
plt.figure(figsize=[10,6])
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
sns.histplot(df['Category'])
# Out:
# <AxesSubplot:xlabel='Category', ylabel='Count'>

# %% [markdown]
# Show all all records of partcular column

# %%
df[df['Title'].isin(["Zumbo's Just Desserts"])]
# Out:
#      Show_Id Category                  Title Director  \
# 7787   s7786  TV Show  Zumbo's Just Desserts      NaN
#
#                             Cast    Country      Release_Date Rating  \
# 7787  Adriano Zumbo, Rachel Khoo  Australia  October 31, 2020  TV-PG
#
#       Duration                                Type  \
# 7787  1 Season  International TV Shows, Reality TV
#
#                                             Description
# 7787  Dessert wizard Adriano Zumbo looks for the nex...

# %% [markdown]
# In which year  highhest number of tv shows and Movies were released? show with bar graph.

# %%
df['Date'] = pd.to_datetime(df["Release_Date"])
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %% [markdown]
# Using value_count() function to know which year highest TV show and Movies were released

# %%
df["Date"].dt.year.value_counts()
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: Date, dtype: int64

# %%
#Show with bar Graph
df["Date"].dt.year.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
#How many movies and shows are in the dataset ? show with the bar graph
df["Category"].value_counts()
# Out:
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
plt.figure(figsize=[10,6])
sns.countplot(df["Category"])
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %%
#show All the movies that were released in 2020
df["Year"]=df["Date"].dt.year
df.head()
df[(df["Category"]=="Movie")& (df["Year"]==2019)].head()
# Out:
#    Show_Id Category   Title             Director  \
# 7       s8    Movie     187       Kevin Reynolds
# 8       s9    Movie     706        Shravan Kumar
# 13     s14    Movie   2,215  Nottapon Boonprakob
# 15     s16    Movie  Oct-01       Kunle Afolayan
# 18     s19    Movie  15-Aug   Swapnaneel Jayakar
#
#                                                  Cast        Country  \
# 7   Samuel L. Jackson, John Heard, Kelly Rowan, Cl...  United States
# 8   Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...          India
# 13                                 Artiwara Kongmalai       Thailand
# 15  Sadiq Daba, David Bailie, Kayode Olaiya, Kehin...        Nigeria
# 18  Rahul Pethe, Mrunmayee Deshpande, Adinath Koth...          India
#
#          Release_Date Rating Duration  \
# 7    November 1, 2019      R  119 min
# 8       April 1, 2019  TV-14  118 min
# 13      March 1, 2019  TV-MA   89 min
# 15  September 1, 2019  TV-14  149 min
# 18     March 29, 2019  TV-14  124 min
#
# ...

# %%
#Show top 5 Directors who gave highest number of tv shows and to netflix

df["Director"].value_counts().head()
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Name: Director, dtype: int64

# %%
#Show all the records where Category is Movies and type is comedies or Country is united states

df[(df["Category"]=="Movie") & (df["Type"]=="Comedies") | (df["Country"] == "United states")].head()
# Out:
#     Show_Id Category                        Title                Director  \
# 33      s34    Movie                 #realityhigh        Fernando Lebrija
# 72      s73    Movie                     17 Again             Burr Steers
# 84      s85    Movie                    21 & Over  Jon Lucas, Scott Moore
# 148    s149    Movie         A Bad Moms Christmas  Jon Lucas, Scott Moore
# 174    s175    Movie  A Futile and Stupid Gesture              David Wain
#
#                                                   Cast               Country  \
# 33   Nesta Cooper, Kate Walsh, John Michael Higgins...         United States
# 72   Zac Efron, Leslie Mann, Matthew Perry, Thomas ...         United States
# 84   Miles Teller, Skylar Astin, Justin Chon, Sarah...         United States
# 148  Mila Kunis, Kristen Bell, Kathryn Hahn, Susan ...  United States, China
# 174  Will Forte, Domhnall Gleeson, Martin Mull, Joe...         United States
#
#           Release_Date Rating Duration      Type  \
# ...

# %%
#Drop the null values from the dataset with the help of dropna() function

df1=df.dropna()
df1.head()
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#         Release_Date Rating  Duration  \
# 1  December 23, 2016  TV-MA    93 min
# 2  December 20, 2018      R    78 min
# 3  November 16, 2017  PG-13    80 min
# 4    January 1, 2020  PG-13   123 min
# 5       July 1, 2017  TV-MA  1 Season
#
# ...

# %%
#In how many TV Show/ movies Rajneesh duggal was casted?
#Ste uesd for convert in string

df1[df1["Cast"].str.contains("Amina Khalil")]
# Out:
#      Show_Id Category     Title         Director  \
# 6         s7    Movie       122  Yasir Al Yasiri
# 6205   s6205    Movie  The Cell   Tarek Al Eryan
# 6913   s6912    Movie  The Suit    Mohammad Adel
#
#                                                    Cast Country  \
# 6     Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...   Egypt
# 6205  Ahmed Ezz, Mohamed Mamdouh, Samer al Masri, Am...   Egypt
# 6913  Tamer Hosny, Akram Hosny, Amina Khalil, Dalal ...   Egypt
#
#            Release_Date Rating Duration  \
# 6          June 1, 2020  TV-MA   95 min
# 6205      June 13, 2019  TV-MA  126 min
# 6913  November 23, 2020  TV-14   97 min
#
#                                                    Type  \
# 6                   Horror Movies, International Movies
# 6205   Action & Adventure, Dramas, International Movies
# 6913  Action & Adventure, Comedies, International Mo...
#
#                                             Description       Date    Year
# ...

# %%
# What are the Different Rating defined by netflix , and how many Movies got TV-14 rating in United States?

df1["Rating"].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-G', 'TV-PG', 'NR', 'PG', 'G',
#        'TV-Y7', 'TV-Y', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
df1[(df1["Rating"]=="TV-14") & (df1["Country"]=="United States")].head()
# Out:
#     Show_Id Category                                   Title  \
# 33      s34    Movie                            #realityhigh
# 47      s48    Movie                           1 Mile to You
# 184    s185    Movie  A Haunting at Silver Falls: The Return
# 232    s233    Movie              A Stoning in Fulham County
# 247    s248    Movie                 A Very Murray Christmas
#
#              Director                                               Cast  \
# 33   Fernando Lebrija  Nesta Cooper, Kate Walsh, John Michael Higgins...
# 47        Leif Tilden  Billy Crudup, Graham Rogers, Liana Liberato, S...
# 184      Teo Konuralp  Laura Flannery, James Cavlo, Harry Hains, Clem...
# 232     Larry Elikann  Ken Olin, Jill Eikenberry, Maureen Mueller, Gr...
# 247     Sofia Coppola  Bill Murray, Miley Cyrus, George Clooney, Chri...
#
#            Country        Release_Date Rating Duration  \
# 33   United States   September 8, 2017  TV-14   99 min
# ...

# %%
# Which Country has highest no. of TV Shows? Show with the bar graph.

tvshow = df1[df1["Category"]=="TV Show"]
tvshow.head()
# Out:
#     Show_Id Category            Title       Director  \
# 5        s6  TV Show               46    Serdar Akar
# 132    s133  TV Show        7 (Seven)    Nizar Shafi
# 218    s219  TV Show  A Queen Is Born   Carla Barros
# 260    s261  TV Show         A.I.C.O.  Kazuya Murata
# 276    s277  TV Show     Abby Hatcher    Kyran Kelly
#
#                                                   Cast                Country  \
# 5    Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...                 Turkey
# 132  Rahman, Havish, Regina Cassandra, Nandita Swet...                  India
# 218                      Gloria Groove, Alexia Twister                 Brazil
# 260  Haruka Shiraishi, Yusuke Kobayashi, Makoto Fur...                  Japan
# 276  Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...  United States, Canada
#
#           Release_Date Rating  Duration  \
# 5         July 1, 2017  TV-MA  1 Season
# 132      July 30, 2019  TV-14  1 Season
# 218  November 11, 2020  TV-14  1 Season
# ...

# %%
tvshow.Country.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>
